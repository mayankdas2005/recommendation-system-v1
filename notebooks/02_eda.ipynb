# %%
import pandas as pd
import json
import gzip

# %%
df = pd.read_parquet('C:/Users/Dell/Desktop/recommendation-engine/data/processed/review_chunks/review_chunk_0.parquet')  
df.head(10)
# Out:
#                         user_id parent_asin  rating  \
# 0  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  B083NRGZMM     3.0
# 1  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  B07N69T6TM     1.0
# 2  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  B01G8JO5F2     5.0
# 3  AGGZ357AO26RQZVRLGU4D4N52DZQ  B001OC5JKY     5.0
# 4  AG2L7H23R5LLKDKLBEF2Q3L2MVDA  B07CJYMRWM     5.0
# 5  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B07CML419K     5.0
# 6  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B07BHHB5RH     5.0
# 7  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B09S6Y5BRG     5.0
# 8  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B01LW71IBJ     5.0
# 9  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B017T99JPG     5.0
#
#                       timestamp
# 0 1970-01-01 00:27:38.185117948
# 1 1970-01-01 00:26:32.678549731
# 2 1970-01-01 00:25:23.093017534
# 3 1970-01-01 00:21:30.278495000
# 4 1970-01-01 00:27:56.601581238
# 5 1970-01-01 00:27:17.522881041
# 6 1970-01-01 00:26:05.130879386
# 7 1970-01-01 00:25:41.356831659
# 8 1970-01-01 00:24:16.772571000
# 9 1970-01-01 00:24:16.772365000

# %%
df['rating'].describe()
# Out:
# count    200000.000000
# mean          4.240860
# std           1.264952
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
df['timestamp'].max()
# Out:
# Timestamp('1970-01-01 00:27:59.181877287')

# %%
len(df['user_id'].unique())
# Out:
# 34256

# %%
user_activity = df['user_id'].value_counts()
power_user = user_activity[user_activity > 5]
print(len(power_user))
# Out:
# 8527

# %%
len(df['user_id'].unique())
# Out:
# 34256

# %%
df.shape
# Out:
# (200000, 4)
